# %% [markdown]
# ## Challenge 2 - What do I do with all this data?
# If you have come this far, that means that you have your data in a single place, preferably ADLS Gen2 container.

# %% [markdown]
# Here is a blueprint to transform ingested data:
#
# - connect properly to ADLS Gen2 container
#
# *NOTE:*
# - you can find Azure Key Vault secret in your Azure subscription in Azure Key Vault
# - you need to configure Secret Scope in Databricks. To do that, open a new tab in your browser and go to https://YOUR-DATABRICKS-WORKSPACE-NAME.azuredatabricks.net/#secrets/createScope
# - you can find more info on [Secret scope](https://docs.microsoft.com/en-us/azure/databricks/security/secrets/secret-scopes#create-an-azure-key-vault-backed-secret-scope-using-the-ui "Secret Scope")

# %%
spark.conf.set(
    "fs.azure.account.key.<ADLSGEN2-STORAGE-ACCOUNT-NAME>.dfs.core.windows.net",
    dbutils.secrets.get(scope="<DATABRICKS-SECRET-SCOPE-NAME>",key="AZURE-KEY-VAUlT-SECRET-NAME"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# - Read parquet file from container in ADLS Gen2 into a DataFrame
# - Create temporary view so that you can run T-SQL queries
# - Try to load some SELECT statement into DataFrame so you can see if you have loaded temp view properly

# %%
# Read parquet using spark.read command
 
# Create temporary table
 
# Use spark.sql to query temporary window
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Repeat the same proccess for subregion parquet

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Repeat the same proccess for country parquet

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# One of the ways to join these tables is to use LEFT JOIN in T-SQL. You should start with joining *Region* and *Subregion* on *RegionId*
#
# *NOTE*: don't forget to create a new temp view where you will save results of a join

# %%
# Initalize dataframe and use spark.sql statement for JOIN

# Save the result to a new temporary view
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# We'll continue with joining *RegionSubregion* view and *Country* view on *SubregionId*
# *NOTE*: don't forget to create a new temp view where you will save results of a join

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Check if you have loaded data correctly

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Now, save that view in a form of a parquet file in output container in ADLS Gen2 storage

# %%
# Write everything from a view where countries, subregions and regions are joined to parquet file

# Write it to your ADLS2 Gen2 storage in output container, preferably to separate folder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# We want to transform and load facttable in parquet format that we got from Azure Data Factory. Repeat the same procedure with creating temp view.
#
# Run SQL command to select only country relevant data such as year, ISO3166_alpha ISO3166_numeric and co2mtco2 and store it to a DataFrame

# %%
# Use spark.sql query and select only columns that you need and save it to temporary table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Now, there is only one thing left to do and that is to save that view as a parquet file in output container on your ADLS Gen2 storage

# %%
# Write everything from a view where cleaned files are joined to parquet file
# Write it to your ADLS2 Gen2 storage in output container, preferably to separate folder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
